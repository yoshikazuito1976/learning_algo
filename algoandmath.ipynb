# %% [markdown]
# <style>
# p {
#   margin-top: 0;
#   margin-bottom: 0;
# }
# </style>
# ## 関数
# 入力が決まると出力が１つに決まる
#  <p style="text-indent:1em">   $y=x^2$</p>
#  <p style="text-indent:1em"> $f(x)=x^2$</p>
# こういう感じで書く

# %%
import numpy as np
import matplotlib.pyplot as plt

# x を -2 から 10 までの範囲で生成
x = np.linspace(-2, 10, 500)

# y = min(x, 5) を要素ごとに適用
y = np.minimum(x, 5)

# グラフを描画
plt.plot(x, y, label='y = min(x, 5)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of y = min(x, 5)')
plt.grid(True)
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.legend()
plt.show()

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/aisyu/algo/venv/lib/python3.10/site-packages (2.2.6)

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'
